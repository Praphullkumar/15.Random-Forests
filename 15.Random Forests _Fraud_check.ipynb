# %% [markdown]
# # Fraud_Check

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix,classification_report,f1_score
from sklearn.preprocessing import StandardScaler

# %%
df=pd.read_csv('Fraud_check.csv')

# %%
df
# Out:
#     Undergrad Marital.Status  Taxable.Income  City.Population  \
# 0          NO         Single           68833            50047
# 1         YES       Divorced           33700           134075
# 2          NO        Married           36925           160205
# 3         YES         Single           50190           193264
# 4          NO        Married           81002            27533
# ..        ...            ...             ...              ...
# 595       YES       Divorced           76340            39492
# 596       YES       Divorced           69967            55369
# 597        NO       Divorced           47334           154058
# 598       YES        Married           98592           180083
# 599        NO       Divorced           96519           158137
#
#      Work.Experience Urban
# 0                 10   YES
# 1                 18   YES
# 2                 30   YES
# 3                 15   YES
# 4                 28    NO
# ..               ...   ...
# 595                7   YES
# 596                2   YES
# 597                0   YES
# 598               17    NO
# 599               16    NO
#
# [600 rows x 6 columns]

# %%
df.dtypes
# Out:
# Undergrad          object
# Marital.Status     object
# Taxable.Income      int64
# City.Population     int64
# Work.Experience     int64
# Urban              object
# dtype: object

# %%
df.isnull().sum()
# Out:
# Undergrad          0
# Marital.Status     0
# Taxable.Income     0
# City.Population    0
# Work.Experience    0
# Urban              0
# dtype: int64

# %%
df = pd.get_dummies(data=df, columns = ['Undergrad','Marital.Status','Urban'])
df
# Out:
#      Taxable.Income  City.Population  Work.Experience  Undergrad_NO  \
# 0             68833            50047               10             1
# 1             33700           134075               18             0
# 2             36925           160205               30             1
# 3             50190           193264               15             0
# 4             81002            27533               28             1
# ..              ...              ...              ...           ...
# 595           76340            39492                7             0
# 596           69967            55369                2             0
# 597           47334           154058                0             1
# 598           98592           180083               17             0
# 599           96519           158137               16             1
#
#      Undergrad_YES  Marital.Status_Divorced  Marital.Status_Married  \
# 0                0                        0                       0
# 1                1                        1                       0
# 2                0                        0                       1
# 3                1                        0                       0
# 4                0                        0                       1
# ..             ...                      ...                     ...
# 595              1                        1                       0
# 596              1                        1                       0
# 597              0                        1                       0
# 598              1                        0                       1
# 599              0                        1                       0
#
#      Marital.Status_Single  Urban_NO  Urban_YES
# 0                        1         0          1
# 1                        0         0          1
# 2                        0         0          1
# 3                        1         0          1
# 4                        0         1          0
# ..                     ...       ...        ...
# 595                      0         0          1
# 596                      0         0          1
# 597                      0         0          1
# 598                      0         1          0
# 599                      0         1          0
#
# [600 rows x 10 columns]

# %%
#treating those who have taxable_income <= 30000 as "Risky" and others are "Good"

# %%
for i in range(len(df['Taxable.Income'])):
    if df['Taxable.Income'][i] <= 30000:
        df['Taxable.Income'][i] = 'risky'
    else:
        df['Taxable.Income'][i] = 'good'
# Out:
# C:\Users\Shree\AppData\Local\Temp/ipykernel_14576/1122919184.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Taxable.Income'][i] = 'good'
# C:\Users\Shree\anaconda3\lib\site-packages\pandas\core\indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)

# %%
df
# Out:
#     Taxable.Income  City.Population  Work.Experience  Undergrad_NO  \
# 0             good            50047               10             1
# 1             good           134075               18             0
# 2             good           160205               30             1
# 3             good           193264               15             0
# 4             good            27533               28             1
# ..             ...              ...              ...           ...
# 595           good            39492                7             0
# 596           good            55369                2             0
# 597           good           154058                0             1
# 598           good           180083               17             0
# 599           good           158137               16             1
#
#      Undergrad_YES  Marital.Status_Divorced  Marital.Status_Married  \
# 0                0                        0                       0
# 1                1                        1                       0
# 2                0                        0                       1
# 3                1                        0                       0
# 4                0                        0                       1
# ..             ...                      ...                     ...
# 595              1                        1                       0
# 596              1                        1                       0
# 597              0                        1                       0
# 598              1                        0                       1
# 599              0                        1                       0
#
#      Marital.Status_Single  Urban_NO  Urban_YES
# 0                        1         0          1
# 1                        0         0          1
# 2                        0         0          1
# 3                        1         0          1
# 4                        0         1          0
# ..                     ...       ...        ...
# 595                      0         0          1
# 596                      0         0          1
# 597                      0         0          1
# 598                      0         1          0
# 599                      0         1          0
#
# [600 rows x 10 columns]

# %% [markdown]
# # model building

# %%
X = df.drop(labels='Taxable.Income',axis=1)
y = df[['Taxable.Income']]

# %%
X
# Out:
#      City.Population  Work.Experience  Undergrad_NO  Undergrad_YES  \
# 0              50047               10             1              0
# 1             134075               18             0              1
# 2             160205               30             1              0
# 3             193264               15             0              1
# 4              27533               28             1              0
# ..               ...              ...           ...            ...
# 595            39492                7             0              1
# 596            55369                2             0              1
# 597           154058                0             1              0
# 598           180083               17             0              1
# 599           158137               16             1              0
#
#      Marital.Status_Divorced  Marital.Status_Married  Marital.Status_Single  \
# 0                          0                       0                      1
# 1                          1                       0                      0
# 2                          0                       1                      0
# 3                          0                       0                      1
# 4                          0                       1                      0
# ..                       ...                     ...                    ...
# 595                        1                       0                      0
# 596                        1                       0                      0
# 597                        1                       0                      0
# 598                        0                       1                      0
# 599                        1                       0                      0
#
#      Urban_NO  Urban_YES
# 0           0          1
# 1           0          1
# 2           0          1
# 3           0          1
# 4           1          0
# ..        ...        ...
# 595         0          1
# 596         0          1
# 597         0          1
# 598         1          0
# 599         1          0
#
# [600 rows x 9 columns]

# %%
y
# Out:
#     Taxable.Income
# 0             good
# 1             good
# 2             good
# 3             good
# 4             good
# ..             ...
# 595           good
# 596           good
# 597           good
# 598           good
# 599           good
#
# [600 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.20,random_state=12)

# %%
#Training data 
X_train.shape , y_train.shape
# Out:
# ((480, 9), (480, 1))

# %%
#Test Data
X_test.shape , y_test.shape
# Out:
# ((120, 9), (120, 1))

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
RF_model = RandomForestClassifier()
RF_model.fit(X_train,y_train)
# Out:
# C:\Users\Shree\AppData\Local\Temp/ipykernel_14576/948055816.py:2: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   RF_model.fit(X_train,y_train)
# RandomForestClassifier()

# %% [markdown]
# ### model tesing

# %%
#Training Data
y_train_pred = RF_model.predict(X_train)

# %%
#Test Data
y_test_pred = RF_model.predict(X_test)

# %% [markdown]
# ### model  evaluation

# %%
from sklearn.metrics import accuracy_score, confusion_matrix

# %%
#Training Data 
accuracy_score(y_train,y_train_pred)
# Out:
# 1.0

# %%
confusion_matrix(y_train,y_train_pred)
# Out:
# array([[369,   0],
#        [  0, 111]], dtype=int64)

# %%
#TEST DATA
accuracy_score(y_test,y_test_pred)
# Out:
# 0.8083333333333333

# %%
confusion_matrix(y_test,y_test_pred)
# Out:
# array([[97, 10],
#        [13,  0]], dtype=int64)

# %%
RF_model.feature_importances_
# Out:
# array([0.5289386 , 0.35016444, 0.01893208, 0.01551913, 0.01602332,
#        0.02064174, 0.01669177, 0.01606562, 0.01702329])

# %%
fi = pd.DataFrame({'feature': list(X_train.columns),
                   'importance': RF_model.feature_importances_}).\
                    sort_values('importance', ascending = False)

# %%
fi
# Out:
#                    feature  importance
# 0          City.Population    0.528939
# 1          Work.Experience    0.350164
# 5   Marital.Status_Married    0.020642
# 2             Undergrad_NO    0.018932
# 8                Urban_YES    0.017023
# 6    Marital.Status_Single    0.016692
# 7                 Urban_NO    0.016066
# 4  Marital.Status_Divorced    0.016023
# 3            Undergrad_YES    0.015519

# %%
#city population is the most important feature
